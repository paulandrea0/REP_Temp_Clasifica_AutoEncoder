# %% [markdown]
# <a href="https://colab.research.google.com/github/paulandrea0/REP_Temp_Clasifica_AutoEncoder/blob/main/REP_Clasifica_comp_Z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Set de datos**

# %% [markdown]
# El set de datos corresponde a señales de sismos volcánicos del tipo VT, LP y Tor

# %% [markdown]
# **1.1 Lectura de datos desde Google Drive**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# Set de entrenamiento y validación para seãnales sísmicas en el componente Z

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import math

#%reset
df_test_1 = pd.read_csv('/gdrive/MyDrive/Sismos/VT_Z_teste.csv')
df_train_1 = pd.read_csv('/gdrive/MyDrive/Sismos/VT_Z_train.csv') 
df_test_2 = pd.read_csv('/gdrive/MyDrive/Sismos/LP_Z_teste.csv')
df_train_2 = pd.read_csv('/gdrive/MyDrive/Sismos/LP_Z_train.csv')
df_test_3 = pd.read_csv('/gdrive/MyDrive/Sismos/TOR_Z_teste.csv')
df_train_3 = pd.read_csv('/gdrive/MyDrive/Sismos/TOR_Z_train.csv')

# %% [markdown]
# **1.2 Aplicando función Mean para quitar el OffSet de los datos**
# Normalización a 3000 muestras por registro.

# %%
# Creando función para retirar el offset de los datos en DataFrame
def mean_norma(df_input):
        return df_input.apply(lambda x: (x-x.mean()), axis=1)  

df_mean_test_1 = mean_norma(df_test_1)  # Señales VT
df_mean_train_1 = mean_norma(df_train_1)
df_mean_test_2 = mean_norma(df_test_2)  # Señales LP
df_mean_train_2 = mean_norma(df_train_2)
df_mean_test_3 = mean_norma(df_test_3)  # Señales Tor
df_mean_train_3 = mean_norma(df_train_3)

print(df_mean_train_1.shape)
print(df_mean_test_1.shape)
print(df_mean_train_2.shape)
print(df_mean_test_2.shape)
print(df_mean_train_3.shape)
print(df_mean_test_3.shape)

# Convirtiendo el dataframe en array
d_train_1 = df_mean_train_1.values
d_train_1 = d_train_1[:, 0:3000]
d_test_1 = df_mean_test_1.values
d_test_1 = d_test_1[:, 0:3000]

d_train_2 = df_mean_train_2.values
d_train_2 = d_train_2[:, 0:3000]
d_test_2 = df_mean_test_2.values
d_test_2 = d_test_2[:, 0:6000]

d_train_3 = df_mean_train_3.values
d_train_3 = d_train_3[:, 0:3000]
d_test_3 = df_mean_test_3.values
d_test_3 = d_test_3[:, 0:3000]

# Dibujando la señal orioginal
n = 3000
fs = 50 # frecuencia de muestreo
t = np.linspace(0,fs,n)
plt.figure(1, figsize=(30, 4))
plt.subplot(231)
plt.plot(t, d_train_1[60])
plt.subplot(232)
plt.plot(t, d_train_2[18])
plt.subplot(233) 
plt.plot(t, d_train_3[38])
plt.subplot(234)
plt.plot(t, d_test_1[44])
plt.subplot(235)
plt.plot(t, d_test_2[34])
plt.subplot(236)
plt.plot(t, d_test_3[4])
# Out:
# (1480, 13348)
# (256, 10993)
# (362, 3000)
# (40, 3000)
# (61, 21494)
# (6, 27408)

# %% [markdown]
# **1.3 Eliminando valores NaN de los arreglos Numpy**

# %%
# Quitando los valores NaN de los array numpy

# Señales VT
d_train_1[np.isnan(d_train_1)] = 0.0
d_test_1[np.isnan(d_test_1)] = 0.0
print(d_train_1.shape)
print(d_test_1.shape)

# Señales LP
d_train_2[np.isnan(d_train_2)] = 0.0
d_test_2[np.isnan(d_test_2)] = 0.0
print(d_train_2.shape)
print(d_test_2.shape)

# Señales Tor`
d_train_3[np.isnan(d_train_3)] = 0.0
d_test_3[np.isnan(d_test_3)] = 0.0
print(d_train_3.shape)
print(d_test_3.shape)

# Graficando
plt.figure(2, figsize=(15, 4))
plt.subplot(231)
plt.plot(t, d_train_1[60])
plt.subplot(232)
plt.plot(t, d_train_2[18])
plt.subplot(233) 
plt.plot(t, d_train_3[38])
plt.subplot(234)
plt.plot(t, d_test_1[44])
plt.subplot(235)
plt.plot(t, d_test_2[34])
plt.subplot(236)
plt.plot(t, d_test_3[4])
# Out:
# (1480, 3000)
# (256, 3000)
# (362, 3000)
# (40, 3000)
# (61, 3000)
# (6, 3000)

# %% [markdown]
# **1.4 Normalización**

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# Señales VT
D_train_s1 = min_max_scaler.fit_transform(d_train_1)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(d_train_1), np.max(d_train_1)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s1), np.max(D_train_s1))) 
D_test_s1 = min_max_scaler.transform(d_test_1)  

# Señales LP
D_train_s2 = min_max_scaler.fit_transform(d_train_2)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(d_train_2), np.max(d_train_2)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s2), np.max(D_train_s2))) 
D_test_s2 = min_max_scaler.transform(d_test_2)  

# Señales Tor
D_train_s3 = min_max_scaler.fit_transform(d_train_3)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(d_train_3), np.max(d_train_3)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s3), np.max(D_train_s3))) 
D_test_s3 = min_max_scaler.transform(d_test_3)  

# Graficando
plt.figure(3, figsize=(20, 4))
plt.subplot(231)
plt.plot(t, D_train_s1[60])
plt.subplot(232)
plt.plot(t, D_train_s2[18])
plt.subplot(233) 
plt.plot(t, D_train_s3[38])
plt.subplot(234)
plt.plot(t, D_test_s1[44])
plt.subplot(235)
plt.plot(t, D_test_s2[34])
plt.subplot(236)
plt.plot(t, D_test_s3[4])
# Out:
# Mínimo y máximo originales: -2710525.5, 2436521.9
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: -151379.3, 151082.0
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: -35374.3, 38363.7
# Mínimo y máximo normalizado: 0.0, 1.0

# %% [markdown]
# # **2. Modelo AutoEncoder para extraer Características (Representaciones de menor dimensión)**

# %% [markdown]
# Importamos TensorFlow 2 que incluye Keras

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print('version de TensorFlow:' + tf.__version__)
# Out:
# version de TensorFlow:2.8.2

# %% [markdown]
# **2.1 Configuración de la arquitectura del Autoencoder**

# %% [markdown]
# Configuramos la arquitectura del modelo de Autoencoder. Esta configuración será reallizada teneindo en cuenta el set de entrenamiento para el conjunto de señales VT.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras import Sequential
from keras.regularizers import l2 # cuando hay sobreajuste la regularización ayuda
# a decartar valores altos en la función de costo. Se puede colocar en cualquier capa
from keras.layers import Dropout  #apagar aleatoriamente algunas neuronas, 
# ayudando a eliminar el sobreajuste
from keras.callbacks import EarlyStopping
np.random.seed(23)

dim_entrada = D_train_s1.shape[1]      
entrada = Input(shape=(dim_entrada,))
print(D_train_s1.shape[1])             

# Encoder
x = Dense(2000, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(1500, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
x = Dense(800, activation='relu')(x)
x = Dropout(0.25)(x)
encoded = Dense(400, activation='relu', name='bottleneck_layer')(x)

# Decoder 
x = Dense(800, activation='relu')(encoded)
x = Dropout(0.25)(x)
x = Dense(1500, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(2000, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
decoded = Dense(3000, activation='sigmoid')(x)

# autoencoder = entrada + decoder (que contiene el encoder)
autoencoder = Model(inputs=entrada, outputs=decoded)

autoencoder.summary()
# Out:
# 3000
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3000)]            0
#
#  dense (Dense)               (None, 2000)              6002000
#
#  dropout (Dropout)           (None, 2000)              0
#
#  dense_1 (Dense)             (None, 1500)              3001500
#
#  dropout_1 (Dropout)         (None, 1500)              0
#
#  dense_2 (Dense)             (None, 800)               1200800
#
#  dropout_2 (Dropout)         (None, 800)               0
#
#  bottleneck_layer (Dense)    (None, 400)               320400
#
#  dense_3 (Dense)             (None, 800)               320800
#
#  dropout_3 (Dropout)         (None, 800)               0
#
#  dense_4 (Dense)             (None, 1500)              1201500
#
#  dropout_4 (Dropout)         (None, 1500)              0
#
#  dense_5 (Dense)             (None, 2000)              3002000
#
#  dropout_5 (Dropout)         (None, 2000)              0
#
#  dense_6 (Dense)             (None, 3000)              6003000
#
# =================================================================
# Total params: 21,052,000
# Trainable params: 21,052,000
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **2.2 Optimización y Entrenamiento**

# %% [markdown]
# La pérdida corresponderá al error absoluto medio(Mean Absolute Error, MAE.
# El optimizador será adam.
# Debido a que el set de datos (entrenamiento y validación) mayor corresponde a las señales sísmicas VT, el autoencoder es entrenado con este set de datos, teniendo en cuenta el desbalance que hay con los demás sets.

# %% [markdown]
# **2.2.1 Entrenando para obtener Representación para Señales VT**

# %% [markdown]
# Una vez entrenado el autoencoder con el set de entenamiento para cada señal, se usa el set de entrenamiento y el set de prueba para obtener las representaciones respectivas de estos dos sets y así permitir conformar nuevos nuevos sets de entrenamiento y validación a partir de las representaciones con menor dimensión.

# %%
autoencoder1 = Model(inputs=entrada, outputs=decoded)
autoencoder1.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder1.fit(D_train_s1, D_train_s1,    
                           epochs=25,
                           batch_size=150,
                           validation_data=(D_test_s1, D_test_s1),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 10/10 [==============================] - 5s 51ms/step - loss: 20.8979 - accuracy: 0.0047 - val_loss: 12.4350 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 10/10 [==============================] - 1s 116ms/step - loss: 8.2393 - accuracy: 0.2331 - val_loss: 4.3087 - val_accuracy: 0.9727
# Epoch 3/25
# 10/10 [==============================] - 1s 62ms/step - loss: 2.6669 - accuracy: 0.5520 - val_loss: 1.2318 - val_accuracy: 0.9727
# Epoch 4/25
# 10/10 [==============================] - 0s 23ms/step - loss: 0.7378 - accuracy: 0.6865 - val_loss: 0.3550 - val_accuracy: 0.9727
# Epoch 5/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.2226 - accuracy: 0.8784 - val_loss: 0.1315 - val_accuracy: 0.9727
# Epoch 6/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1062 - accuracy: 0.9669 - val_loss: 0.0899 - val_accuracy: 0.9727
# Epoch 7/25
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0636 - accuracy: 0.9750 - val_loss: 0.0470 - val_accuracy: 0.9727
# Epoch 8/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0396 - accuracy: 0.9750 - val_loss: 0.0390 - val_accuracy: 0.9727
# Epoch 9/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0282 - accuracy: 0.9750 - val_loss: 0.0255 - val_accuracy: 0.9727
# Epoch 10/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0235 - accuracy: 0.9750 - val_loss: 0.0429 - val_accuracy: 0.9727
# Epoch 11/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0221 - accuracy: 0.9750 - val_loss: 0.0226 - val_accuracy: 0.9727
# Epoch 12/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0155 - accuracy: 0.9750 - val_loss: 0.0263 - val_accuracy: 0.9727
# Epoch 13/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0142 - accuracy: 0.9750 - val_loss: 0.0158 - val_accuracy: 0.9727
# Epoch 14/25
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0118 - accuracy: 0.9750 - val_loss: 0.0145 - val_accuracy: 0.9727
# Epoch 15/25
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0106 - accuracy: 0.9750 - val_loss: 0.0153 - val_accuracy: 0.9727
# Epoch 16/25
# 10/10 [==============================] - 1s 158ms/step - loss: 0.0093 - accuracy: 0.9750 - val_loss: 0.0152 - val_accuracy: 0.9727
# Epoch 17/25
# 10/10 [==============================] - 0s 24ms/step - loss: 0.0085 - accuracy: 0.9750 - val_loss: 0.0149 - val_accuracy: 0.9727
# Epoch 18/25
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0086 - accuracy: 0.9750 - val_loss: 0.0130 - val_accuracy: 0.9727
# Epoch 19/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0079 - accuracy: 0.9750 - val_loss: 0.0142 - val_accuracy: 0.9727
# Epoch 20/25
# 10/10 [==============================] - 1s 146ms/step - loss: 0.0078 - accuracy: 0.9750 - val_loss: 0.0133 - val_accuracy: 0.9727
# Epoch 21/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0072 - accuracy: 0.9750 - val_loss: 0.0129 - val_accuracy: 0.9727
# Epoch 22/25
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0072 - accuracy: 0.9750 - val_loss: 0.0129 - val_accuracy: 0.9727
# Epoch 23/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0068 - accuracy: 0.9750 - val_loss: 0.0129 - val_accuracy: 0.9727
# Epoch 24/25
# 10/10 [==============================] - 0s 17ms/step - loss: 0.0067 - accuracy: 0.9750 - val_loss: 0.0122 - val_accuracy: 0.9727
# Epoch 25/25
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0066 - accuracy: 0.9750 - val_loss: 0.0124 - val_accuracy: 0.9727

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales VT, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_1 = bottleneck.predict(D_test_s1)
rep_train_1 = bottleneck.predict(D_train_s1)
print(rep_test_1.shape)
print(rep_train_1.shape)
# Out:
# (256, 400)
# (1480, 400)

# %% [markdown]
# **2.2.2 Entrenando para obtener Representación para Señales LP**

# %% [markdown]
# Usamos la misma arquitectura del autoencoder, sin embargo, entrenamos con señales LP

# %%
autoencoder2 = Model(inputs=entrada, outputs=decoded)
autoencoder2.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder2.fit(D_train_s2, D_train_s2,    
                           epochs=25,
                           batch_size=50,
                           validation_data=(D_test_s2, D_test_s2),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 3s 247ms/step - loss: 0.2079 - accuracy: 0.0028 - val_loss: 0.2015 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1904 - accuracy: 0.0000e+00 - val_loss: 0.1709 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1560 - accuracy: 0.0000e+00 - val_loss: 0.1147 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.1085 - accuracy: 0.0000e+00 - val_loss: 0.1123 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0937 - accuracy: 0.0055 - val_loss: 0.0729 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 8/8 [==============================] - 1s 113ms/step - loss: 0.0763 - accuracy: 0.0166 - val_loss: 0.0725 - val_accuracy: 0.0250
# Epoch 7/25
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0708 - accuracy: 0.0359 - val_loss: 0.0600 - val_accuracy: 0.0250
# Epoch 8/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0618 - accuracy: 0.0387 - val_loss: 0.0523 - val_accuracy: 0.0250
# Epoch 9/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0558 - accuracy: 0.0359 - val_loss: 0.0467 - val_accuracy: 0.0250
# Epoch 10/25
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0500 - accuracy: 0.0387 - val_loss: 0.0489 - val_accuracy: 0.0250
# Epoch 11/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0494 - accuracy: 0.0331 - val_loss: 0.0434 - val_accuracy: 0.0250
# Epoch 12/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0441 - accuracy: 0.0470 - val_loss: 0.0432 - val_accuracy: 0.0250
# Epoch 13/25
# 8/8 [==============================] - 1s 131ms/step - loss: 0.0412 - accuracy: 0.0414 - val_loss: 0.0475 - val_accuracy: 0.0250
# Epoch 14/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0431 - accuracy: 0.0525 - val_loss: 0.0432 - val_accuracy: 0.0250
# Epoch 15/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0417 - accuracy: 0.1215 - val_loss: 0.0427 - val_accuracy: 0.0250
# Epoch 16/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0402 - accuracy: 0.2265 - val_loss: 0.0394 - val_accuracy: 0.2750
# Epoch 17/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0393 - accuracy: 0.2348 - val_loss: 0.0383 - val_accuracy: 0.2750
# Epoch 18/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0381 - accuracy: 0.2707 - val_loss: 0.0387 - val_accuracy: 0.0250
# Epoch 19/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0373 - accuracy: 0.2845 - val_loss: 0.0386 - val_accuracy: 0.2750
# Epoch 20/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0374 - accuracy: 0.2983 - val_loss: 0.0376 - val_accuracy: 0.2750
# Epoch 21/25
# 8/8 [==============================] - 1s 142ms/step - loss: 0.0367 - accuracy: 0.3315 - val_loss: 0.0375 - val_accuracy: 0.2750
# Epoch 22/25
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0365 - accuracy: 0.3315 - val_loss: 0.0375 - val_accuracy: 0.2750
# Epoch 23/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0367 - accuracy: 0.3260 - val_loss: 0.0370 - val_accuracy: 0.2750
# Epoch 24/25
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0367 - accuracy: 0.3260 - val_loss: 0.0375 - val_accuracy: 0.2750
# Epoch 25/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0374 - accuracy: 0.3591 - val_loss: 0.0413 - val_accuracy: 0.2750

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales LP, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_2 = bottleneck.predict(D_test_s2)
print(rep_test_2.shape)
rep_train_2 = bottleneck.predict(D_train_s2)
print(rep_train_2.shape)
# Out:
# (40, 400)
# (362, 400)

# %% [markdown]
# **2.2.3 Entrenando para obtener Representación para Señales Tor**

# %% [markdown]
# Usamos la misma arquitectura del autoencoder, sin embargo, entrenamos con señales Tor

# %%
autoencoder3 = Model(inputs=entrada, outputs=decoded)
autoencoder3.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder3.fit(D_train_s3, D_train_s3,    
                           epochs=25,
                           batch_size=2,
                           validation_data=(D_test_s3, D_test_s3),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 31/31 [==============================] - 3s 72ms/step - loss: 0.1845 - accuracy: 0.0000e+00 - val_loss: 0.1390 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.1145 - accuracy: 0.0000e+00 - val_loss: 0.1158 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 31/31 [==============================] - 4s 124ms/step - loss: 0.1020 - accuracy: 0.0164 - val_loss: 0.1092 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0998 - accuracy: 0.0328 - val_loss: 0.1074 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 31/31 [==============================] - 1s 21ms/step - loss: 0.0988 - accuracy: 0.0328 - val_loss: 0.1081 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0987 - accuracy: 0.1148 - val_loss: 0.1090 - val_accuracy: 0.1667
# Epoch 7/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0987 - accuracy: 0.1639 - val_loss: 0.1074 - val_accuracy: 0.1667
# Epoch 8/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0967 - accuracy: 0.1475 - val_loss: 0.1057 - val_accuracy: 0.1667
# Epoch 9/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0962 - accuracy: 0.1311 - val_loss: 0.1076 - val_accuracy: 0.1667
# Epoch 10/25
# 31/31 [==============================] - 1s 22ms/step - loss: 0.0953 - accuracy: 0.0492 - val_loss: 0.1044 - val_accuracy: 0.1667
# Epoch 11/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0945 - accuracy: 0.1803 - val_loss: 0.1054 - val_accuracy: 0.1667
# Epoch 12/25
# 31/31 [==============================] - 1s 47ms/step - loss: 0.0941 - accuracy: 0.1475 - val_loss: 0.1039 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0922 - accuracy: 0.0492 - val_loss: 0.1034 - val_accuracy: 0.1667
# Epoch 14/25
# 31/31 [==============================] - 1s 24ms/step - loss: 0.0924 - accuracy: 0.2131 - val_loss: 0.1023 - val_accuracy: 0.1667
# Epoch 15/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0919 - accuracy: 0.2131 - val_loss: 0.1040 - val_accuracy: 0.1667
# Epoch 16/25
# 31/31 [==============================] - 1s 43ms/step - loss: 0.0912 - accuracy: 0.2131 - val_loss: 0.1020 - val_accuracy: 0.1667
# Epoch 17/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0913 - accuracy: 0.2131 - val_loss: 0.1014 - val_accuracy: 0.1667
# Epoch 18/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0903 - accuracy: 0.2131 - val_loss: 0.1023 - val_accuracy: 0.1667
# Epoch 19/25
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0903 - accuracy: 0.1967 - val_loss: 0.1023 - val_accuracy: 0.1667
# Epoch 20/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0898 - accuracy: 0.2131 - val_loss: 0.1012 - val_accuracy: 0.1667
# Epoch 21/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0893 - accuracy: 0.2131 - val_loss: 0.1007 - val_accuracy: 0.1667
# Epoch 22/25
# 31/31 [==============================] - 2s 52ms/step - loss: 0.0890 - accuracy: 0.2131 - val_loss: 0.1015 - val_accuracy: 0.1667
# Epoch 23/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0907 - accuracy: 0.1803 - val_loss: 0.1009 - val_accuracy: 0.1667
# Epoch 24/25
# 31/31 [==============================] - 1s 23ms/step - loss: 0.0891 - accuracy: 0.1639 - val_loss: 0.1002 - val_accuracy: 0.1667
# Epoch 25/25
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0884 - accuracy: 0.2131 - val_loss: 0.1000 - val_accuracy: 0.1667

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales Tor, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_3 = bottleneck.predict(D_test_s3)
print(rep_test_3.shape)
rep_train_3 = bottleneck.predict(D_train_s3)
print(rep_train_3.shape)
# Out:
# (6, 400)
# (61, 400)

# %% [markdown]
# **2.3. Representaciones de menor Dimensión**

# %% [markdown]
# Una vez entrenado el autoencoder extraemos la información aprendida de la capa de menor dimensión, la cual consigue representar mejor la señal.
#
# A continuación se presenta una representación por cada tipo de señal solo para poder identificar las diferntes representaciones obtenidas.

# %%
Representación = Model(inputs=entrada, outputs=encoded)
Representación.summary

# Observamos cómo el Autoencoder consigue representar 

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(3,2,1)
plt.plot(rep_train_1[dato])
plt.legend(labels=["Train VT"])
plt.subplot(3,2,2)
plt.plot(rep_test_1[dato])
plt.legend(labels=["Test VT"])
plt.subplot(3,2,3)
plt.plot(rep_train_2[dato])
plt.legend(labels=["Train LP"])
plt.subplot(3,2,4)
plt.plot(rep_test_2[dato])
plt.legend(labels=["Test LP"])
plt.subplot(3,2,5)
plt.plot(rep_train_3[dato])
plt.legend(labels=["Rain Tor"])
plt.subplot(3,2,6)
plt.plot(rep_test_3[dato])
plt.legend(labels=["Test Tor"])

# %% [markdown]
# # **3. Modelo de AutoEncoder para Clasificación**

# %% [markdown]
# Con las representaciones obtenidas con el modelo de autoencoder anterior, estas son normalizadas y presentadas a un nuevo autoencoder para su posterior clasificación bajo el enfoque de distribución del error de reconstrucción.

# %% [markdown]
# **3.1 Normalización de las representaciones**

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# Señales VT
Rep_train_s1 = min_max_scaler.fit_transform(rep_train_1)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_1), np.max(rep_train_1)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(Rep_train_s1), np.max(Rep_train_s1))) 
Rep_test_s1 = min_max_scaler.transform(rep_test_1)  

# Señales LP
Rep_train_s2 = min_max_scaler.fit_transform(rep_train_2)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_2), np.max(rep_train_2)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s2), np.max(D_train_s2))) 
Rep_test_s2 = min_max_scaler.transform(rep_test_2)  

# Señales Tor
Rep_train_s3 = min_max_scaler.fit_transform(rep_train_3)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_3), np.max(rep_train_3)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s3), np.max(D_train_s3))) 
Rep_test_s3 = min_max_scaler.transform(rep_test_3)  

# Graficando
n3 = Rep_train_s1.shape[1]
t3 = np.linspace(0,fs,n3) # creando un vector de tiempo
print(len(t3))
plt.figure(figsize=(20, 4))
plt.subplot(231)
plt.plot(t3, Rep_train_s1[60])
plt.legend(labels=["Train VT"])
plt.subplot(232)
plt.plot(t3, Rep_train_s2[18])
plt.legend(labels=["Train LP"])
plt.subplot(233) 
plt.plot(t3, Rep_train_s3[38])
plt.legend(labels=["Train Tor"])
plt.subplot(234)
plt.plot(t3, Rep_test_s1[44])
plt.legend(labels=["Test VT"])
plt.subplot(235)
plt.plot(t3, Rep_test_s2[34])
plt.legend(labels=["Test VT"])
plt.subplot(236)
plt.plot(t3, Rep_test_s3[4])
plt.legend(labels=["Test VT"])
# Out:
# Mínimo y máximo originales: 0.0, 0.1
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 0.2
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 0.1
# Mínimo y máximo normalizado: 0.0, 1.0
# 400

# %% [markdown]
# **3.2 Modelo de AutoEncoder para posterior Clasificación**

# %% [markdown]
# A continuación se configura la arquitectura del AutoEncoder para que este aprenda la reconstrucción con el set de datos de entrenamiento para las señales VT que es de la cual se tiene un set con un mayor número de ejemplos.

# %%
np.random.seed(23)

dim_entrada = Rep_train_s1.shape[1]      
entrada = Input(shape=(dim_entrada,))
print(Rep_train_s1.shape[1])             

# Encoder
x = Dense(300, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(150, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(100, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
encoded = Dense(50, activation='relu', name='bottleneck_layer')(x)

# Decoder 
x = Dense(100, activation='relu')(encoded)
x = Dropout(0.25)(x)
x = Dense(150, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(300, activation='relu')(x)
x = Dropout(0.25)(x)
decoded = Dense(400, activation='sigmoid')(x)

# autoencoder = entrada + decoder (que contiene el encoder)
autoencoder = Model(inputs=entrada, outputs=decoded)

autoencoder.summary()
# Out:
# 400
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 400)]             0
#
#  dense_18 (Dense)            (None, 150)               60150
#
#  dropout_15 (Dropout)        (None, 150)               0
#
#  dense_19 (Dense)            (None, 100)               15100
#
#  dropout_16 (Dropout)        (None, 100)               0
#
#  bottleneck_layer (Dense)    (None, 50)                5050
#
#  dense_20 (Dense)            (None, 100)               5100
#
#  dropout_17 (Dropout)        (None, 100)               0
#
#  dense_21 (Dense)            (None, 150)               15150
#
#  dropout_18 (Dropout)        (None, 150)               0
#
#  dense_22 (Dense)            (None, 300)               45300
#
#  dropout_19 (Dropout)        (None, 300)               0
#
#  dense_23 (Dense)            (None, 400)               120400
#
# =================================================================
# Total params: 266,250
# Trainable params: 266,250
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **3.3 Optimización y Entrenamiento**

# %% [markdown]
# Lapérdida corresponderá al error absoluto medio (MAE) y el optimizador será adam.

# %%
autoencoder.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder.fit(Rep_train_s1, Rep_train_s1,    
                           epochs=20,
                           batch_size=150,
                           validation_data=(Rep_test_s1, Rep_test_s1),    
                           shuffle=True)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 2s 40ms/step - loss: 1.9590 - accuracy: 0.0014 - val_loss: 1.5788 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 10/10 [==============================] - 0s 6ms/step - loss: 1.2443 - accuracy: 0.0041 - val_loss: 1.0302 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.9192 - accuracy: 0.0014 - val_loss: 0.7922 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7036 - accuracy: 6.7568e-04 - val_loss: 0.6038 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5349 - accuracy: 6.7568e-04 - val_loss: 0.4583 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4054 - accuracy: 6.7568e-04 - val_loss: 0.3473 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 6.7568e-04 - val_loss: 0.2634 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2328 - accuracy: 6.7568e-04 - val_loss: 0.2003 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1771 - accuracy: 6.7568e-04 - val_loss: 0.1530 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 6.7568e-04 - val_loss: 0.1175 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1039 - accuracy: 6.7568e-04 - val_loss: 0.0908 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0804 - accuracy: 0.0047 - val_loss: 0.0707 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0626 - accuracy: 0.0095 - val_loss: 0.0556 - val_accuracy: 0.0039
# Epoch 14/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0493 - accuracy: 0.0047 - val_loss: 0.0441 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0391 - accuracy: 0.0108 - val_loss: 0.0353 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0314 - accuracy: 0.0047 - val_loss: 0.0287 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 0.0027 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.0020 - val_loss: 0.0194 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.0020 - val_loss: 0.0162 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.0047 - val_loss: 0.0135 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# # **4. Clasificación**

# %% [markdown]
# Identificamos qué tan bien el modelo es capaz de reconstruir las señales para las cuales fue entrenado (VT) como también las otras señales de tal forma que se pueda identificar el error de reconstrucción.

# %% [markdown]
# **3.1 Identificación de la distribución del error**

# %%
rec_1 = autoencoder(Rep_test_s1).numpy()
rec_2 = autoencoder(Rep_test_s2).numpy()
rec_3 = autoencoder(Rep_test_s3).numpy()

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(3,1,1)
plt.plot(Rep_test_s1[dato],'b')
plt.plot(rec_1[dato],'r')
plt.fill_between(np.arange(400), rec_1[dato], Rep_test_s1[dato], color='lightcoral')
plt.legend(labels=["Original normal", "Reconstruction", "Error"])
plt.subplot(3,1,2)
plt.plot(Rep_test_s2[dato],'b')
plt.plot(rec_2[dato],'r')
plt.fill_between(np.arange(400), rec_2[dato], Rep_test_s2[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])
plt.subplot(3,1,3)
plt.plot(Rep_test_s3[dato],'b')
plt.plot(rec_3[dato],'r')
plt.fill_between(np.arange(400), rec_3[dato], Rep_test_s3[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])

# %%
rec_1 = autoencoder.predict(Rep_test_s1)
rec_2 = autoencoder.predict(Rep_test_s2)
rec_3 = autoencoder.predict(Rep_test_s3)

loss_1 = tf.keras.losses.mae(rec_1, Rep_test_s1)
loss_2 = tf.keras.losses.mae(rec_2, Rep_test_s2)
loss_3 = tf.keras.losses.mae(rec_3, Rep_test_s3)

plt.figure(figsize=(15,8))
plt.hist(loss_1[None,:], bins=100, alpha=0.75, label='VT (1)')
plt.hist(loss_2[None,:], bins=100, alpha=0.75, color='#ff521b', label='LP (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, color='#020122', label='Tor (3)')

plt.xlabel('Pérdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend(loc='upper right')
plt.vlines(0.08,0,70,'k')

# %% [markdown]
# **3.2 Definición del humbral de clasificación**

# %%
umbral = np.mean(loss_1) + np.std(loss_1)
print("Umbral: ", umbral)
# Out:
# Umbral:  0.02727777

# %% [markdown]
# **3.3 Sensitividad y Especificidad**

# %% [markdown]
# *   **Verdaderos positivos (TP):** anormales que han sido correctamente clasificados como anormales
# *   **Falsos negativos (FN):** anormales que han sido clasificados erróneamente como normales
# *   **Verdaderos negativos (TN):** normales que han sido correctamente clasificados como normales
# *   **Falsos positivos (FP):** normales que han sido clasificados erróneamente como anormales

# %% [markdown]
# La **sensitividad** mide la proporción de anormales que fueron detectados correctamente como anormales. Una sensitividad del 100% detectará a todos los pacientes enfermos:
#
# $$Sensitividad = \dfrac{TP}{TP+FN}$$
#
# La **especificidad** mide la proporción de normales que fueron detectados correctamente como normales. Una especificidad del 100% detectará a todos los pacientes sanos:
# $$Especificidad = \dfrac{TN}{TN+FP}$$

# %%
# Definiendo funciones para la clasificación individual
def identificar(modelo, datos, umbral):
  reconstrucciones = modelo(datos)
  perdida = tf.keras.losses.mae(reconstrucciones, datos)
  return tf.math.less(perdida, umbral)

def calcular_sensitividad(identificacion, titulo):
  TP = np.count_nonzero(~identificacion)
  FN = np.count_nonzero(identificacion)
  sen = 100*(TP/(TP+FN))

  print(titulo + ': {:.1f}%'.format(sen))

def calcular_especificidad(identificacion, titulo):
  TN = np.count_nonzero(identificacion)
  FP = np.count_nonzero(~identificacion)
  esp = 100*(TN/(TN+FP))

  print(titulo + ': {:.1f}%'.format(esp))
  return esp

# %%
# Identificación del tipo de señal
pred_1 = identificar(autoencoder, Rep_test_s1, umbral)
pred_2 = identificar(autoencoder, Rep_test_s2, umbral)
pred_3 = identificar(autoencoder, Rep_test_s3, umbral)

# Calculo de Especificidad
esp_1 = calcular_especificidad(pred_1,'Especificidad (cat. VT, VT)')

# Cálculo de Sensitividad
sen_2 = calcular_sensitividad(pred_2,'Sensitividad (cat. LP, NO VTs)')
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. Tor, NO VTs)')
# Out:
# Especificidad (cat. VT, VT): 99.6%
# Sensitividad (cat. LP, NO VTs): 100.0%
# Sensitividad (cat. Tor, NO VTs): 100.0%

# %% [markdown]
# **3.3 Clasificador II para las señales restantes: LP y Tor**

# %% [markdown]
# Optimización y entrenamiento

# %%
autoencoder.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder.fit(Rep_train_s2, Rep_train_s2,    
                           epochs=15,
                           batch_size=30,
                           validation_data=(Rep_test_s2, Rep_test_s2),    
                           shuffle=True)
# Out:
# Epoch 1/15
# 13/13 [==============================] - 1s 27ms/step - loss: 0.1858 - accuracy: 0.0028 - val_loss: 0.1431 - val_accuracy: 0.0250
# Epoch 2/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0991 - accuracy: 0.0110 - val_loss: 0.0439 - val_accuracy: 0.0250
# Epoch 3/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.0166 - val_loss: 0.0136 - val_accuracy: 0.0250
# Epoch 4/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.0138 - val_loss: 0.0091 - val_accuracy: 0.0250
# Epoch 5/15
# 13/13 [==============================] - 1s 5ms/step - loss: 0.0148 - accuracy: 0.0276 - val_loss: 0.0111 - val_accuracy: 0.0250
# Epoch 6/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.0138 - val_loss: 0.0070 - val_accuracy: 0.0250
# Epoch 7/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.0249 - val_loss: 0.0063 - val_accuracy: 0.0250
# Epoch 8/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.0552 - val_loss: 0.0060 - val_accuracy: 0.0250
# Epoch 9/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.1077 - val_loss: 0.0067 - val_accuracy: 0.0250
# Epoch 10/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 0.1381 - val_loss: 0.0056 - val_accuracy: 0.0250
# Epoch 11/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.1298 - val_loss: 0.0055 - val_accuracy: 0.0250
# Epoch 12/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.1215 - val_loss: 0.0054 - val_accuracy: 0.0250
# Epoch 13/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.1713 - val_loss: 0.0053 - val_accuracy: 0.0250
# Epoch 14/15
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.2017 - val_loss: 0.0065 - val_accuracy: 0.0250
# Epoch 15/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 0.2348 - val_loss: 0.0057 - val_accuracy: 0.0250

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %%
rec_2 = autoencoder(Rep_test_s2).numpy()
rec_3 = autoencoder(Rep_test_s3).numpy()

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
plt.plot(Rep_test_s2[dato],'b')
plt.plot(rec_2[dato],'r')
plt.fill_between(np.arange(400), rec_2[dato], Rep_test_s2[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])
plt.subplot(2,1,2)
plt.plot(Rep_test_s3[dato],'b')
plt.plot(rec_3[dato],'r')
plt.fill_between(np.arange(400), rec_3[dato], Rep_test_s3[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])

# %%
rec_2 = autoencoder.predict(Rep_test_s2)
rec_3 = autoencoder.predict(Rep_test_s3)

loss_2 = tf.keras.losses.mae(rec_2, Rep_test_s2)
loss_3 = tf.keras.losses.mae(rec_3, Rep_test_s3)

plt.figure(figsize=(15,8))
plt.hist(loss_2[None,:], bins=100, alpha=0.75, color='#ff521b', label='LP (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, color='#020122', label='Tor (3)')

plt.xlabel('Pérdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend(loc='upper right')
plt.vlines(0.08,0,70,'k')

# %%
umbral = np.mean(loss_2) + np.std(loss_2)
print("Umbral: ", umbral)
# Out:
# Umbral:  0.017109476

# %%
# Identificación del tipo de señal
pred_2 = identificar(autoencoder, Rep_test_s2, umbral)
pred_3 = identificar(autoencoder, Rep_test_s3, umbral)

# Calculo de Especificidad
esp_2 = calcular_especificidad(pred_2,'Especificidad (cat. LP, LP)')

# Cálculo de Sensitividad
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. Tor, NO LPs)')
# Out:
# Especificidad (cat. LP, LP): 97.5%
# Sensitividad (cat. Tor, NO LPs): 100.0%
